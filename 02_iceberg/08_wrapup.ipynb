# %% [markdown]
# NOTE: THIS NOTEBOOK IS WORK IN PROGRESS.
#
# Reference ELT/Spark from time travel section?
# A section about the standard itself and what it covers?
# other topics, like views? variant?
#
# equality and position deletes? updates?
#
# cleanup of metadata/snapshots and orphaned files? distinguishing/tagging original and rewritten data?
# query engines and drastic schema evolution?
# Limitations of Iceberg (no indexes)
#
# Show maybe the trick of generating temporary iceberg tables  on Parquet files to do zero-copy ETL? Netflix style?
